# %%
# !pip install xlrd

# %%
import pandas as pd

# %%
df = pd.read_excel('All_data_FIW_2013-2022.xlsx', sheet_name = 1)

# %%
df
# Out:
#      Freedom in the World 2013-2022 Raw Data   Unnamed: 1 Unnamed: 2  \
# 0                          Country/Territory       Region        C/T
# 1                                   Abkhazia      Eurasia          t
# 2                                Afghanistan         Asia          c
# 3                                    Albania       Europe          c
# 4                                    Algeria       Africa          c
# ...                                      ...          ...        ...
# 2091                               West Bank  Middle East          t
# 2092                          Western Sahara       Africa          t
# 2093                                   Yemen  Middle East          c
# 2094                                  Zambia       Africa          c
# 2095                                Zimbabwe       Africa          c
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...

# %%
df['Unnamed: 4'].value_counts()[
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\cs418env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\cs418env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\cs418env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 4'
#
# The above exception was the direct cause of the following exception:
#
# ...
