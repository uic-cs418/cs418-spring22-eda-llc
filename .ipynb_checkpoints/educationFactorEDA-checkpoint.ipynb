# %% [markdown]
# ## EDA For Literacy Rate Affecting The Status Of The Countries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns;

# %% [markdown]
# ### Import the literacy rate for each country for time period = 2018

# %%
edu = pd.read_excel("Literacy-rate_2021-1.xlsx", sheet_name = 2, nrows = 203, header = 0)
edu = edu.drop(columns = ['Gender','Source'])
edu = edu.drop([0])
edu = edu.drop(columns=edu.columns[6])
edu = edu.rename(columns={"Unnamed: 9": "Time period"})
edu = edu.reset_index(drop=True)
edu
# Out:
#     ISO3                 Countries and areas Region Sub-region  \
# 0    AFG                         Afghanistan     SA         SA
# 1    ALB                             Albania    ECA       EECA
# 2    DZA                             Algeria   MENA       MENA
# 3    AND                             Andorra    ECA         WE
# 4    AGO                              Angola    SSA        ESA
# ..   ...                                 ...    ...        ...
# 197  VEN  Venezuela (Bolivarian Republic of)    LAC        LAC
# 198  VNM                            Viet Nam    EAP        EAP
# 199  YEM                               Yemen   MENA       MENA
# 200  ZMB                              Zambia    SSA        ESA
# 201  ZWE                            Zimbabwe    SSA        ESA
#
#     Development Regions      Total Time period
# 0       Least Developed  65.420547        2018
# 1        More Developed  99.330002        2018
# 2        Less Developed  97.426521        2018
# 3        More Developed        NaN         NaN
# 4       Least Developed        NaN         NaN
# ..                  ...        ...         ...
# 197      Less Developed        NaN         NaN
# 198      Less Developed  98.408096        2018
# 199     Least Developed        NaN         NaN
# 200     Least Developed  92.091568        2018
# 201      Less Developed        NaN         NaN
#
# [202 rows x 7 columns]

# %% [markdown]
# Cleaning the data by dropping the countries marked as "Not Classified" in Development Regions

# %%
edu = edu[edu['Development Regions'] != 'Not Classified']
edu
# Out:
#     ISO3                 Countries and areas Region Sub-region  \
# 0    AFG                         Afghanistan     SA         SA
# 1    ALB                             Albania    ECA       EECA
# 2    DZA                             Algeria   MENA       MENA
# 3    AND                             Andorra    ECA         WE
# 4    AGO                              Angola    SSA        ESA
# ..   ...                                 ...    ...        ...
# 197  VEN  Venezuela (Bolivarian Republic of)    LAC        LAC
# 198  VNM                            Viet Nam    EAP        EAP
# 199  YEM                               Yemen   MENA       MENA
# 200  ZMB                              Zambia    SSA        ESA
# 201  ZWE                            Zimbabwe    SSA        ESA
#
#     Development Regions      Total Time period
# 0       Least Developed  65.420547        2018
# 1        More Developed  99.330002        2018
# 2        Less Developed  97.426521        2018
# 3        More Developed        NaN         NaN
# 4       Least Developed        NaN         NaN
# ..                  ...        ...         ...
# 197      Less Developed        NaN         NaN
# 198      Less Developed  98.408096        2018
# 199     Least Developed        NaN         NaN
# 200     Least Developed  92.091568        2018
# 201      Less Developed        NaN         NaN
#
# [196 rows x 7 columns]

# %% [markdown]
# ### Import All Data FIW To Compare The Status of the Countries with The Literacy Rate for 2018 Edition

# %%
allData = pd.read_excel("All_data_FIW_2013-2022.xlsx", sheet_name = 1, header=1)
allData = allData[allData['Edition'] == 2018]
allData = allData.reset_index(drop=True)
allData
# Out:
#     Country/Territory       Region C/T  Edition Status  PR rating  CL rating  \
# 0            Abkhazia      Eurasia   t     2018     PF          4          5
# 1         Afghanistan         Asia   c     2018     NF          5          6
# 2             Albania       Europe   c     2018     PF          3          3
# 3             Algeria       Africa   c     2018     NF          6          5
# 4             Andorra       Europe   c     2018      F          1          1
# ..                ...          ...  ..      ...    ...        ...        ...
# 204         West Bank  Middle East   t     2018     NF          7          5
# 205    Western Sahara       Africa   t     2018     NF          7          7
# 206             Yemen  Middle East   c     2018     NF          7          6
# 207            Zambia       Africa   c     2018     PF          4          4
# 208          Zimbabwe       Africa   c     2018     NF          6          5
#
#      A1  A2  A3  ...  F3  F4   F  G1  G2  G3  G4   G  CL  Total
# 0     3   2   1  ...   1   1   4   1   1   2   1   5  23     41
# 1     1   0   1  ...   0   1   2   0   1   0   1   2  14     26
# 2     3   3   2  ...   2   3   9   3   2   2   2   9  40     68
# 3     1   1   1  ...   2   2   6   2   2   2   1   7  25     35
# 4     4   4   4  ...   4   3  15   4   4   4   4  16  57     96
# ..   ..  ..  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..    ...
# 204   0   0   2  ...   0   1   5   1   1   2   1   5  23     28
# 205   0   0   0  ...   0   0   0   1   1   2   0   4   7      4
# 206   0   0   0  ...   0   1   2   0   1   1   0   2  12     13
# 207   2   2   2  ...   2   2   8   3   2   2   1   8  33     55
# 208   0   1   1  ...   0   1   3   2   1   1   1   5  20     30
#
# [209 rows x 44 columns]
